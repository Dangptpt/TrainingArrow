# %%
! pip install langchain unstructured[all-docs] pydantic lxml openai chromadb tiktoken
# Out:
# Requirement already satisfied: langchain in d:\hust study\intern\training\.venv\lib\site-packages (0.2.3)
# Requirement already satisfied: pydantic in d:\hust study\intern\training\.venv\lib\site-packages (2.7.4)
# Collecting lxml
#   Using cached lxml-5.2.2-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: openai in d:\hust study\intern\training\.venv\lib\site-packages (1.35.3)
# Requirement already satisfied: chromadb in d:\hust study\intern\training\.venv\lib\site-packages (0.5.2)
# Requirement already satisfied: tiktoken in d:\hust study\intern\training\.venv\lib\site-packages (0.7.0)
# Collecting unstructured[all-docs]
#   Downloading unstructured-0.14.9-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: PyYAML>=5.3 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (0.2.5)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (0.2.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain) (8.3.0)
# Collecting chardet (from unstructured[all-docs])
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured[all-docs])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured[all-docs])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting nltk (from unstructured[all-docs])
#   Using cached nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting tabulate (from unstructured[all-docs])
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: beautifulsoup4 in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (4.12.3)
# Collecting emoji (from unstructured[all-docs])
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: dataclasses-json in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (0.6.7)
# Collecting python-iso639 (from unstructured[all-docs])
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured[all-docs])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---- --------------------------------- 122.9/981.5 kB 7.5 MB/s eta 0:00:01
#      --------- ---------------------------- 235.5/981.5 kB 4.9 MB/s eta 0:00:01
#      ----------- -------------------------- 307.2/981.5 kB 3.8 MB/s eta 0:00:01
#      --------------- ---------------------- 389.1/981.5 kB 3.5 MB/s eta 0:00:01
#      ----------------- -------------------- 460.8/981.5 kB 2.6 MB/s eta 0:00:01
#      ----------------------- -------------- 614.4/981.5 kB 3.0 MB/s eta 0:00:01
#      -------------------------- ----------- 686.1/981.5 kB 2.9 MB/s eta 0:00:01
#      -------------------------------- ----- 829.4/981.5 kB 2.8 MB/s eta 0:00:01
#      ---------------------------------- --- 890.9/981.5 kB 2.7 MB/s eta 0:00:01
#      -------------------------------------- 981.5/981.5 kB 2.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting rapidfuzz (from unstructured[all-docs])
#   Downloading rapidfuzz-3.9.4-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: backoff in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (2.2.1)
# Requirement already satisfied: typing-extensions in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (4.12.2)
# Collecting unstructured-client (from unstructured[all-docs])
#   Downloading unstructured_client-0.23.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: wrapt in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: tqdm in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (4.66.4)
# Collecting openpyxl (from unstructured[all-docs])
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pillow-heif (from unstructured[all-docs])
#   Downloading pillow_heif-0.17.0-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Collecting pdf2image (from unstructured[all-docs])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pikepdf (from unstructured[all-docs])
#   Downloading pikepdf-9.0.0-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: pandas in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (2.2.2)
# Collecting google-cloud-vision (from unstructured[all-docs])
#   Downloading google_cloud_vision-3.7.2-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting xlrd (from unstructured[all-docs])
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[all-docs])
#   Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pypdf in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (4.2.0)
# Collecting markdown (from unstructured[all-docs])
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting unstructured-inference==0.7.36 (from unstructured[all-docs])
#   Downloading unstructured_inference-0.7.36-py3-none-any.whl.metadata (5.9 kB)
# Collecting pypandoc (from unstructured[all-docs])
#   Downloading pypandoc-1.13-py3-none-any.whl.metadata (16 kB)
# Collecting effdet (from unstructured[all-docs])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting python-docx>=1.1.2 (from unstructured[all-docs])
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: networkx in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured[all-docs]) (3.3)
# Collecting pytesseract (from unstructured[all-docs])
#   Downloading pytesseract-0.3.10-py3-none-any.whl.metadata (11 kB)
# Collecting python-oxmsg (from unstructured[all-docs])
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-pptx<=0.6.23 (from unstructured[all-docs])
#   Using cached python_pptx-0.6.23-py3-none-any.whl.metadata (18 kB)
# Collecting pdfminer.six (from unstructured[all-docs])
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting onnx (from unstructured[all-docs])
#   Downloading onnx-1.16.1-cp311-cp311-win_amd64.whl.metadata (16 kB)
# Collecting layoutparser (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: python-multipart in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (0.0.9)
# Requirement already satisfied: huggingface-hub in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (0.23.3)
# Requirement already satisfied: opencv-python!=4.7.0.68 in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (4.10.0.82)
# Requirement already satisfied: onnxruntime>=1.17.0 in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (1.18.0)
# Requirement already satisfied: matplotlib in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (3.9.0)
# Requirement already satisfied: torch in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (2.3.1)
# Collecting timm (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading timm-1.0.7-py3-none-any.whl.metadata (47 kB)
#      ---------------------------------------- 0.0/47.5 kB ? eta -:--:--
#      ---------------------------------------- 47.5/47.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.25.1 in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (4.41.2)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\hust study\intern\training\.venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in d:\hust study\intern\training\.venv\lib\site-packages (from pydantic) (2.18.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\hust study\intern\training\.venv\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\hust study\intern\training\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\hust study\intern\training\.venv\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: sniffio in d:\hust study\intern\training\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: build>=1.0.3 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\hust study\intern\training\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.1)
# Requirement already satisfied: posthog>=2.4.0 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in d:\hust study\intern\training\.venv\lib\site-packages (from chromadb) (3.10.4)
# Requirement already satisfied: regex>=2022.1.18 in d:\hust study\intern\training\.venv\lib\site-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\hust study\intern\training\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\hust study\intern\training\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\hust study\intern\training\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\hust study\intern\training\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\hust study\intern\training\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in d:\hust study\intern\training\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: packaging>=19.1 in d:\hust study\intern\training\.venv\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in d:\hust study\intern\training\.venv\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in d:\hust study\intern\training\.venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in d:\hust study\intern\training\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in d:\hust study\intern\training\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in d:\hust study\intern\training\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in d:\hust study\intern\training\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in d:\hust study\intern\training\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.1.1)
# Requirement already satisfied: certifi in d:\hust study\intern\training\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in d:\hust study\intern\training\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\hust study\intern\training\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in d:\hust study\intern\training\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\hust study\intern\training\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\hust study\intern\training\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\hust study\intern\training\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\hust study\intern\training\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\hust study\intern\training\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in d:\hust study\intern\training\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\hust study\intern\training\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: coloredlogs in d:\hust study\intern\training\.venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\hust study\intern\training\.venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (24.3.25)
# Requirement already satisfied: protobuf in d:\hust study\intern\training\.venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (4.25.3)
# Requirement already satisfied: sympy in d:\hust study\intern\training\.venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (1.12.1)
# Requirement already satisfied: deprecated>=1.2.6 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (65.5.0)
# Requirement already satisfied: asgiref~=3.0 in d:\hust study\intern\training\.venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in d:\hust study\intern\training\.venv\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: Pillow>=3.3.2 in d:\hust study\intern\training\.venv\lib\site-packages (from python-pptx<=0.6.23->unstructured[all-docs]) (10.3.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<=0.6.23->unstructured[all-docs])
#   Using cached XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\hust study\intern\training\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in d:\hust study\intern\training\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: click>=8.0.0 in d:\hust study\intern\training\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in d:\hust study\intern\training\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\hust study\intern\training\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in d:\hust study\intern\training\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in d:\hust study\intern\training\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in d:\hust study\intern\training\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in d:\hust study\intern\training\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: soupsieve>1.2 in d:\hust study\intern\training\.venv\lib\site-packages (from beautifulsoup4->unstructured[all-docs]) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\hust study\intern\training\.venv\lib\site-packages (from dataclasses-json->unstructured[all-docs]) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\hust study\intern\training\.venv\lib\site-packages (from dataclasses-json->unstructured[all-docs]) (0.9.0)
# Collecting torchvision (from effdet->unstructured[all-docs])
#   Downloading torchvision-0.18.1-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting pycocotools>=2.0.2 (from effdet->unstructured[all-docs])
#   Downloading pycocotools-2.0.8-cp311-cp311-win_amd64.whl.metadata (1.1 kB)
# Collecting omegaconf>=2.0 (from effdet->unstructured[all-docs])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in d:\hust study\intern\training\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (2.19.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in d:\hust study\intern\training\.venv\lib\site-packages (from google-cloud-vision->unstructured[all-docs]) (1.23.0)
# Requirement already satisfied: joblib in d:\hust study\intern\training\.venv\lib\site-packages (from nltk->unstructured[all-docs]) (1.4.2)
# Collecting et-xmlfile (from openpyxl->unstructured[all-docs])
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pytz>=2020.1 in d:\hust study\intern\training\.venv\lib\site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\hust study\intern\training\.venv\lib\site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Collecting cryptography>=36.0.0 (from pdfminer.six->unstructured[all-docs])
#   Using cached cryptography-42.0.8-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Collecting olefile (from python-oxmsg->unstructured[all-docs])
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured[all-docs])
#   Downloading deepdiff-7.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured[all-docs])
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mypy-extensions>=1.0.0 in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-client->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in d:\hust study\intern\training\.venv\lib\site-packages (from unstructured-client->unstructured[all-docs]) (1.6.0)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured[all-docs])
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cffi>=1.12 in d:\hust study\intern\training\.venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.16.0)
# Collecting ordered-set<4.2.0,>=4.1.0 (from deepdiff>=6.0->unstructured-client->unstructured[all-docs])
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: dnspython>=2.0.0 in d:\hust study\intern\training\.venv\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in d:\hust study\intern\training\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.62.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\hust study\intern\training\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\hust study\intern\training\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\hust study\intern\training\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in d:\hust study\intern\training\.venv\lib\site-packages (from huggingface-hub->unstructured-inference==0.7.36->unstructured[all-docs]) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\hust study\intern\training\.venv\lib\site-packages (from huggingface-hub->unstructured-inference==0.7.36->unstructured[all-docs]) (2024.6.0)
# Requirement already satisfied: zipp>=0.5 in d:\hust study\intern\training\.venv\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\hust study\intern\training\.venv\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in d:\hust study\intern\training\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (2.4)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[all-docs])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ---------------------------------------- 0.0/117.0 kB ? eta -:--:--
#      ---------------------------------------- 117.0/117.0 kB ? eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: contourpy>=1.0.1 in d:\hust study\intern\training\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\hust study\intern\training\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\hust study\intern\training\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\hust study\intern\training\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\hust study\intern\training\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (3.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\hust study\intern\training\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\hust study\intern\training\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Requirement already satisfied: safetensors in d:\hust study\intern\training\.venv\lib\site-packages (from timm->unstructured-inference==0.7.36->unstructured[all-docs]) (0.4.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in d:\hust study\intern\training\.venv\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[all-docs]) (2021.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in d:\hust study\intern\training\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (10.0)
# Requirement already satisfied: scipy in d:\hust study\intern\training\.venv\lib\site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[all-docs]) (1.13.1)
# Collecting iopath (from layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ---------------------------------------- 0.0/42.2 kB ? eta -:--:--
#      ---------------------------------------- 42.2/42.2 kB 2.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pdfplumber (from layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading pdfplumber-0.11.1-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in d:\hust study\intern\training\.venv\lib\site-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (1.3.0)
# Requirement already satisfied: pycparser in d:\hust study\intern\training\.venv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.22)
# Requirement already satisfied: pyreadline3 in d:\hust study\intern\training\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in d:\hust study\intern\training\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: intel-openmp==2021.* in d:\hust study\intern\training\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->unstructured-inference==0.7.36->unstructured[all-docs]) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in d:\hust study\intern\training\.venv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->unstructured-inference==0.7.36->unstructured[all-docs]) (2021.12.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in d:\hust study\intern\training\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Collecting portalocker (from iopath->layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading portalocker-2.10.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading pypdfium2-4.30.0-py3-none-win_amd64.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.5 kB ? eta -:--:--
#      ---------------------------------------- 48.5/48.5 kB ? eta 0:00:00
# Requirement already satisfied: pywin32>=226 in d:\hust study\intern\training\.venv\lib\site-packages (from portalocker->iopath->layoutparser->unstructured-inference==0.7.36->unstructured[all-docs]) (306)
# Downloading unstructured_inference-0.7.36-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.4 kB ? eta -:--:--
#    ---------------------------------------- 56.4/56.4 kB ? eta 0:00:00
# Using cached lxml-5.2.2-cp311-cp311-win_amd64.whl (3.8 MB)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/244.3 kB ? eta -:--:--
#    -------------------------------------- 244.3/244.3 kB 340.2 kB/s eta 0:00:00
# Using cached python_pptx-0.6.23-py3-none-any.whl (471 kB)
# Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl (14 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/199.4 kB ? eta -:--:--
#    ---------------- ----------------------- 81.9/199.4 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 174.1/199.4 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 199.4/199.4 kB 2.0 MB/s eta 0:00:00
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.5 kB ? eta -:--:--
#    ---------------------------------------- 112.5/112.5 kB 6.4 MB/s eta 0:00:00
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#    ------------- -------------------------- 143.4/431.4 kB 4.3 MB/s eta 0:00:01
#    -------------------------- ------------- 286.7/431.4 kB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 358.4/431.4 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 431.4/431.4 kB 2.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_cloud_vision-3.7.2-py2.py3-none-any.whl (459 kB)
#    ---------------------------------------- 0.0/459.6 kB ? eta -:--:--
#    ------------ --------------------------- 143.4/459.6 kB 4.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 266.2/459.6 kB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 368.6/459.6 kB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 430.1/459.6 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 459.6/459.6 kB 2.4 MB/s eta 0:00:00
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Downloading onnx-1.16.1-cp311-cp311-win_amd64.whl (14.4 MB)
#    ---------------------------------------- 0.0/14.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/14.4 MB 3.6 MB/s eta 0:00:04
#     --------------------------------------- 0.2/14.4 MB 3.6 MB/s eta 0:00:04
#     --------------------------------------- 0.3/14.4 MB 3.3 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/14.4 MB 3.0 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/14.4 MB 3.0 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/14.4 MB 2.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.7/14.4 MB 2.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/14.4 MB 2.6 MB/s eta 0:00:06
#    -- ------------------------------------- 0.9/14.4 MB 2.6 MB/s eta 0:00:06
#    -- ------------------------------------- 1.1/14.4 MB 2.7 MB/s eta 0:00:06
#    --- ------------------------------------ 1.1/14.4 MB 2.7 MB/s eta 0:00:05
#    --- ------------------------------------ 1.2/14.4 MB 2.7 MB/s eta 0:00:05
#    --- ------------------------------------ 1.4/14.4 MB 2.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.5/14.4 MB 2.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.5/14.4 MB 2.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.5/14.4 MB 2.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.5/14.4 MB 2.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.5/14.4 MB 2.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.5/14.4 MB 2.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.5/14.4 MB 2.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.1/14.4 MB 2.5 MB/s eta 0:00:05
#    ------ --------------------------------- 2.3/14.4 MB 2.6 MB/s eta 0:00:05
#    ------ --------------------------------- 2.3/14.4 MB 2.6 MB/s eta 0:00:05
#    ------ --------------------------------- 2.5/14.4 MB 2.6 MB/s eta 0:00:05
#    ------- -------------------------------- 2.6/14.4 MB 2.5 MB/s eta 0:00:05
#    ------- -------------------------------- 2.6/14.4 MB 2.6 MB/s eta 0:00:05
#    ------- -------------------------------- 2.7/14.4 MB 2.6 MB/s eta 0:00:05
#    ------- -------------------------------- 2.9/14.4 MB 2.6 MB/s eta 0:00:05
#    -------- ------------------------------- 2.9/14.4 MB 2.5 MB/s eta 0:00:05
#    -------- ------------------------------- 3.1/14.4 MB 2.6 MB/s eta 0:00:05
#    -------- ------------------------------- 3.2/14.4 MB 2.5 MB/s eta 0:00:05
#    -------- ------------------------------- 3.2/14.4 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.4/14.4 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.5/14.4 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.5/14.4 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.7/14.4 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.8/14.4 MB 2.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.9/14.4 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.0/14.4 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.1/14.4 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.2/14.4 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.3/14.4 MB 2.5 MB/s eta 0:00:05
#    ------------ --------------------------- 4.4/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 4.5/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 4.6/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 4.7/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 4.7/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 4.8/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 5.0/14.4 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 5.1/14.4 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 5.2/14.4 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 5.3/14.4 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 5.4/14.4 MB 2.5 MB/s eta 0:00:04
#    --------------- ------------------------ 5.5/14.4 MB 2.5 MB/s eta 0:00:04
#    --------------- ------------------------ 5.5/14.4 MB 2.5 MB/s eta 0:00:04
#    --------------- ------------------------ 5.5/14.4 MB 2.5 MB/s eta 0:00:04
#    --------------- ------------------------ 5.5/14.4 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 5.9/14.4 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.0/14.4 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.1/14.4 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.2/14.4 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.3/14.4 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.3/14.4 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.4/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------------ --------------------- 6.6/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------------ --------------------- 6.7/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------------ --------------------- 6.7/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------------- -------------------- 6.9/14.4 MB 2.5 MB/s eta 0:00:04
#    ------------------- -------------------- 7.0/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 7.0/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 7.2/14.4 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 7.2/14.4 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 7.3/14.4 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 7.5/14.4 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 7.5/14.4 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 7.6/14.4 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 7.8/14.4 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 7.9/14.4 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.0/14.4 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.1/14.4 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.2/14.4 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.3/14.4 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.4/14.4 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.5/14.4 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.5/14.4 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.5/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------------ --------------- 8.8/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------------ --------------- 8.8/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------------ --------------- 8.9/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------------ --------------- 9.0/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 9.1/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 9.2/14.4 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 9.3/14.4 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 9.5/14.4 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 9.5/14.4 MB 2.5 MB/s eta 0:00:02
#    -------------------------- ------------- 9.7/14.4 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 9.7/14.4 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 9.9/14.4 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 10.0/14.4 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 10.0/14.4 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.2/14.4 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.3/14.4 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.4/14.4 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 10.5/14.4 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 10.6/14.4 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 10.6/14.4 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 10.7/14.4 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 10.9/14.4 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 10.9/14.4 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 11.1/14.4 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 11.2/14.4 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 11.3/14.4 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 11.4/14.4 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 11.5/14.4 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 11.6/14.4 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 11.8/14.4 MB 2.6 MB/s eta 0:00:02
#    -------------------------------- ------- 11.8/14.4 MB 2.6 MB/s eta 0:00:02
#    --------------------------------- ------ 12.0/14.4 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 12.1/14.4 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 12.1/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.3/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.4/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.5/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.6/14.4 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.7/14.4 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.8/14.4 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.9/14.4 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.0/14.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.1/14.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.2/14.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.3/14.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.4/14.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 13.5/14.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.4 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 13.7/14.4 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 13.8/14.4 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 13.9/14.4 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 14.0/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  14.1/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  14.3/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.4/14.4 MB 2.5 MB/s eta 0:00:00
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ------------------------ --------------- 153.6/250.9 kB 4.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 225.3/250.9 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 2.6 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    - -------------------------------------- 0.1/5.6 MB 8.3 MB/s eta 0:00:01
#    -- ------------------------------------- 0.3/5.6 MB 3.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/5.6 MB 3.2 MB/s eta 0:00:02
#    --- ------------------------------------ 0.5/5.6 MB 2.9 MB/s eta 0:00:02
# ...
#    ---------------- ----------------------- 7.9/19.2 MB 2.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 7.9/19.2 MB 2.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 8.0/19.2 MB 2.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 8.1/19.2 MB 2.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.3/19.2 MB 2.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.3/19.2 MB 2.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.4/19.2 MB 2.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.6/19.2 MB 2.5 MB/s eta 0:00:05
#    ------------------ --------------------- 8.6/19.2 MB 2.5 MB/s eta 0:00:05
#    ------------------ --------------------- 8.7/19.2 MB 2.5 MB/s eta 0:00:05
#    ------------------ --------------------- 8.9/19.2 MB 2.5 MB/s eta 0:00:05
#    ------------------ --------------------- 8.9/19.2 MB 2.5 MB/s eta 0:00:05
#    ------------------ --------------------- 9.0/19.2 MB 2.5 MB/s eta 0:00:05
#    ------------------ --------------------- 9.1/19.2 MB 2.5 MB/s eta 0:00:05
#    ------------------- -------------------- 9.2/19.2 MB 2.5 MB/s eta 0:00:05
#    ------------------- -------------------- 9.3/19.2 MB 2.5 MB/s eta 0:00:04
#    ------------------- -------------------- 9.4/19.2 MB 2.5 MB/s eta 0:00:04
#    ------------------- -------------------- 9.5/19.2 MB 2.5 MB/s eta 0:00:04
#    -------------------- ------------------- 9.6/19.2 MB 2.5 MB/s eta 0:00:04
#    -------------------- ------------------- 9.8/19.2 MB 2.5 MB/s eta 0:00:04
#    -------------------- ------------------- 9.8/19.2 MB 2.5 MB/s eta 0:00:04
#    -------------------- ------------------- 9.9/19.2 MB 2.5 MB/s eta 0:00:04
#    -------------------- ------------------- 10.0/19.2 MB 2.5 MB/s eta 0:00:04
#    --------------------- ------------------ 10.1/19.2 MB 2.5 MB/s eta 0:00:04
#    --------------------- ------------------ 10.2/19.2 MB 2.5 MB/s eta 0:00:04
#    --------------------- ------------------ 10.3/19.2 MB 2.5 MB/s eta 0:00:04
#    --------------------- ------------------ 10.4/19.2 MB 2.5 MB/s eta 0:00:04
#    --------------------- ------------------ 10.5/19.2 MB 2.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 10.6/19.2 MB 2.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 10.7/19.2 MB 2.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 10.8/19.2 MB 2.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 11.0/19.2 MB 2.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 11.0/19.2 MB 2.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.1/19.2 MB 2.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.3/19.2 MB 2.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.3/19.2 MB 2.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.5/19.2 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 11.5/19.2 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 11.6/19.2 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 11.8/19.2 MB 2.5 MB/s eta 0:00:03
#    ------------------------ --------------- 11.9/19.2 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 12.0/19.2 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 12.1/19.2 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 12.2/19.2 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 12.3/19.2 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 12.4/19.2 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 12.5/19.2 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 12.6/19.2 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 12.7/19.2 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 12.8/19.2 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 12.9/19.2 MB 2.5 MB/s eta 0:00:03
#    --------------------------- ------------ 13.0/19.2 MB 2.5 MB/s eta 0:00:03
#    --------------------------- ------------ 13.1/19.2 MB 2.5 MB/s eta 0:00:03
#    --------------------------- ------------ 13.2/19.2 MB 2.5 MB/s eta 0:00:03
#    --------------------------- ------------ 13.3/19.2 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.4/19.2 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.5/19.2 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.6/19.2 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.7/19.2 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.8/19.2 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 13.9/19.2 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.0/19.2 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.1/19.2 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.2/19.2 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.3/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 14.4/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 14.5/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 14.6/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 14.7/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 14.8/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 14.9/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 15.0/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 15.1/19.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 15.2/19.2 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 15.4/19.2 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 15.4/19.2 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 15.5/19.2 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 15.6/19.2 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 15.7/19.2 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 15.8/19.2 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 16.0/19.2 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 16.0/19.2 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 16.1/19.2 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 16.2/19.2 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.3/19.2 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.4/19.2 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.5/19.2 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.7/19.2 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.7/19.2 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 16.8/19.2 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 16.9/19.2 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.0/19.2 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.1/19.2 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.2/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 17.3/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 17.4/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 17.5/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 17.6/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 17.7/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 17.8/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 17.9/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 18.0/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 18.2/19.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 18.3/19.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 18.4/19.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 18.5/19.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 18.6/19.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 18.7/19.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  18.8/19.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  18.9/19.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  19.0/19.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  19.2/19.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 2.5 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ---------------------------------------- 0.0/114.6 kB ? eta -:--:--
#    -------------------------------- ------- 92.2/114.6 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 114.6/114.6 kB 2.2 MB/s eta 0:00:00
# Downloading torchvision-0.18.1-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.1/1.2 MB 8.9 MB/s eta 0:00:01
#    ------ --------------------------------- 0.2/1.2 MB 3.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.2 MB 3.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.2 MB 3.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.2 MB 3.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.2 MB 3.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.2 MB 3.1 MB/s eta 0:00:01
#    --------------------------- ------------ 0.8/1.2 MB 2.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.9/1.2 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.2 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 1.1/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 2.6 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pdfplumber-0.11.1-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.9 kB ? eta -:--:--
#    ---------------------------------------- 57.9/57.9 kB 3.2 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/2.9 MB 3.9 MB/s eta 0:00:01
#    --- ------------------------------------ 0.3/2.9 MB 4.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.9 MB 3.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.4/2.9 MB 3.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.6/2.9 MB 3.0 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/2.9 MB 3.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.8/2.9 MB 2.8 MB/s eta 0:00:01
#    ------------ --------------------------- 0.9/2.9 MB 2.8 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.9 MB 2.7 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/2.9 MB 2.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.2/2.9 MB 2.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.2/2.9 MB 2.7 MB/s eta 0:00:01
#    ------------------- -------------------- 1.4/2.9 MB 2.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.5/2.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.9 MB 2.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.7/2.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.8/2.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.9 MB 2.6 MB/s eta 0:00:01
#    --------------------------- ------------ 2.0/2.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.1/2.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------ --------- 2.2/2.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 2.3/2.9 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 2.3/2.9 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 2.4/2.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.5/2.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 2.8/2.9 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.9 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 2.5 MB/s eta 0:00:00
# Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: langdetect, antlr4-python3-runtime, iopath
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993250 sha256=b9e9b9dc5050d632226f43a69687124d36bc07911781020ed1e03b19c1bc74e3
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\0a\f2\b2\e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
#   Building wheel for antlr4-python3-runtime (pyproject.toml): started
#   Building wheel for antlr4-python3-runtime (pyproject.toml): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144577 sha256=8d64a3889a354df5d1ae587b101ee2aebc6dbf6a8c0988d6f68f4ac11408a876
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\1a\97\32\461f837398029ad76911109f07047fde1d7b661a147c7c56d1
#   Building wheel for iopath (pyproject.toml): started
#   Building wheel for iopath (pyproject.toml): finished with status 'done'
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31543 sha256=eed16f2e201db2d42ca82187d19d760a0b02109d67fc2bf4f9d5b688745684e2
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\ba\5e\16\6117f8fe7e9c0c161a795e10d94645ebcf301ccbd01f66d8ec
# Successfully built langdetect antlr4-python3-runtime iopath
# Installing collected packages: filetype, antlr4-python3-runtime, XlsxWriter, xlrd, unstructured.pytesseract, tabulate, rapidfuzz, python-magic, python-iso639, pytesseract, pypdfium2, pypandoc, portalocker, pillow-heif, pdf2image, ordered-set, onnx, omegaconf, olefile, markdown, lxml, langdetect, jsonpath-python, et-xmlfile, emoji, chardet, requests-toolbelt, python-pptx, python-oxmsg, python-docx, pikepdf, openpyxl, nltk, iopath, deepdiff, cryptography, unstructured-client, torchvision, pycocotools, pdfminer.six, unstructured, timm, pdfplumber, layoutparser, google-cloud-vision, effdet, unstructured-inference
# Successfully installed XlsxWriter-3.2.0 antlr4-python3-runtime-4.9.3 chardet-5.2.0 cryptography-42.0.8 deepdiff-7.0.1 effdet-0.4.1 emoji-2.12.1 et-xmlfile-1.1.0 filetype-1.2.0 google-cloud-vision-3.7.2 iopath-0.1.10 jsonpath-python-1.0.6 langdetect-1.0.9 layoutparser-0.3.4 lxml-5.2.2 markdown-3.6 nltk-3.8.1 olefile-0.47 omegaconf-2.3.0 onnx-1.16.1 openpyxl-3.1.5 ordered-set-4.1.0 pdf2image-1.17.0 pdfminer.six-20231228 pdfplumber-0.11.1 pikepdf-9.0.0 pillow-heif-0.17.0 portalocker-2.10.0 pycocotools-2.0.8 pypandoc-1.13 pypdfium2-4.30.0 pytesseract-0.3.10 python-docx-1.1.2 python-iso639-2024.4.27 python-magic-0.4.27 python-oxmsg-0.0.1 python-pptx-0.6.23 rapidfuzz-3.9.4 requests-toolbelt-1.0.0 tabulate-0.9.0 timm-1.0.7 torchvision-0.18.1 unstructured-0.14.9 unstructured-client-0.23.8 unstructured-inference-0.7.36 unstructured.pytesseract-0.3.12 xlrd-2.0.1
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Data Loading
#
# ### Partition PDF tables, text, and images
#
# * Use [Unstructured](https://unstructured-io.github.io/unstructured/) to partition elements

# %%
from typing import Any

from pydantic import BaseModel
from unstructured.partition.pdf import partition_pdf

# Get elements
raw_pdf_elements = partition_pdf(
    filename= "quyche.pdf",
    extract_images_in_pdf=True,
    infer_table_structure=True,
    chunking_strategy="by_title",
    max_characters=4000,
    new_after_n_chars=3800,
    combine_text_under_n_chars=2000,
)
# Out:
# config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/46.8M [00:00<?, ?B/s]
# Some weights of the model checkpoint at microsoft/table-transformer-structure-recognition were not used when initializing TableTransformerForObjectDetection: ['model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing TableTransformerForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TableTransformerForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Create a dictionary to store counts of each type
category_counts = {}

for element in raw_pdf_elements:
    category = str(type(element))
    if category in category_counts:
        category_counts[category] += 1
    else:
        category_counts[category] = 1

# Unique_categories will have unique elements
unique_categories = set(category_counts.keys())
category_counts
# Out:
# {"<class 'unstructured.documents.elements.CompositeElement'>": 19,
#  "<class 'unstructured.documents.elements.Table'>": 3}

# %%
import base64

text_elements = []
table_elements = []
image_elements = []

# Function to encode images
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

for element in raw_pdf_elements:
    if 'CompositeElement' in str(type(element)):
        text_elements.append(element)
    elif 'Table' in str(type(element)):
        table_elements.append(element)

table_elements = [i.text for i in table_elements]
text_elements = [i.text for i in text_elements]

# Tables
print(len(table_elements))

# Text
print(len(text_elements))
# Out:
# 3
# 19

# %% [markdown]
# ## Multi-vector retriever
#
# Use [multi-vector-retriever](https://python.langchain.com/docs/modules/data_connection/retrievers/multi_vector#summary).
#
# Summaries are used to retrieve raw tables and / or raw chunks of text.

# %% [markdown]
# ### Add to vectorstore
#
# Use [Multi Vector Retriever](https://python.langchain.com/docs/modules/data_connection/retrievers/multi_vector#summary) with summaries.

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
import os
api_key = os.environ["OPENAI_API_KEY"]

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema.messages import HumanMessage, AIMessage

chain_gpt_35 = ChatOpenAI(model="gpt-3.5-turbo-0125", max_tokens=1024, api_key=api_key)
# chain_gpt_4_vision = ChatOpenAI(model="gpt-4-vision-preview", max_tokens=1024)

# Function for text summaries
def summarize_text(text_element):
    prompt = f"Tóm tắt đoạn văn sau:\n\n{text_element}\n\nTóm tắt:"
    response = chain_gpt_35.invoke([HumanMessage(content=prompt)])
    return response.content

# Function for table summaries
def summarize_table(table_element):
    prompt = f"Tóm tắt bảng sau:\n\n{table_element}\n\nTóm tắt:"
    response = chain_gpt_35.invoke([HumanMessage(content=prompt)])
    return response.content

# Function for image summaries
# def summarize_image(encoded_image):
#     prompt = [
#         AIMessage(content="You are a bot that is good at analyzing images."),
#         HumanMessage(content=[
#             {"type": "text", "text": "Describe the contents of this image."},
#             {
#                 "type": "image_url",
#                 "image_url": {
#                     "url": f"data:image/jpeg;base64,{encoded_image}"
#                 },
#             },
#         ])
#     ]
#     response = chain_gpt_4_vision.invoke(prompt)
#     return response.content

# %%
# Processing table elements with feedback and sleep
table_summaries = []
for i, te in enumerate(table_elements):
    summary = summarize_table(te)
    table_summaries.append(summary)
    print(summary)
# Out:
# Bảng này mô tả cách điểm số được chuyển đổi từ thang điểm 10 sang thang điểm 4. Điểm số từ 9,5 đến 10 sẽ được chuyển thành A+, từ 8,5 đến 9,4 chuyển thành A, từ 8,0 đến 8,4 chuyển thành B+ và tiếp tục như vậy. Điểm chữ tương ứng với điểm số được xác định dựa trên khoảng điểm số nằm trong. Không đạt sẽ được gán điểm số là 0.
# Bảng trình độ học vị và số tín chỉ tích lũy của sinh viên trong các năm học. Sinh viên năm thứ nhất dưới 32 tín chỉ, sinh viên năm thứ hai từ 32 đến dưới 64 tín chỉ, sinh viên năm thứ ba từ 64 đến dưới 96 tín chỉ, sinh viên năm thứ tư từ 96 đến dưới 128 tín chỉ, và sinh viên năm thứ năm từ 128 tín chỉ trở lên.
# Bảng trên phân loại học lực của sinh viên dựa trên điểm trung bình tích lũy. Sinh viên được xếp loại từ xuất sắc đến kém dưới 1,0 tùy theo khoảng điểm trung bình tích lũy của họ.

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.schema.document import Document
from langchain.storage import InMemoryStore
from langchain.vectorstores import Chroma
import uuid

# Initialize the vector store and storage layer
vectorstore = Chroma(collection_name="summaries", embedding_function=OpenAIEmbeddings(api_key=api_key))
store = InMemoryStore()
id_key = "doc_id"
# Initialize the retriever
retriever = MultiVectorRetriever(vectorstore=vectorstore, docstore=store, id_key=id_key)

# Function to add documents to the retriever
def add_documents_to_retriever(summaries, original_contents):
    doc_ids = [str(uuid.uuid4()) for _ in summaries]
    summary_docs = [
        Document(page_content=s, metadata={id_key: doc_ids[i]})
        for i, s in enumerate(summaries)
    ]
    retriever.vectorstore.add_documents(summary_docs)
    retriever.docstore.mset(list(zip(doc_ids, original_contents)))

# %%
add_documents_to_retriever(table_summaries, table_elements)
vectorstore.persist()

# %% [markdown]
# # Table retrieval
#
# The most complex table in the paper:

# %%
persit_directory = "vectorstore"
vectorstore = Chroma(collection_name="summaries", 
                     embedding_function=OpenAIEmbeddings(api_key=api_key),
                     persist_directory=persit_directory)

retriever = MultiVectorRetriever(vectorstore=vectorstore, docstore=store, id_key=id_key)

retriever.get_relevant_documents(
    "tích lũy được 50 tín chỉ là sinh viên năm mấy?"
)

# %% [markdown]
# We can retrieve this image summary:

# %%
from langchain.schema.runnable import RunnablePassthrough
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser

template = """Answer the question based only on the following context, which can include text, images and tables:
{context}
Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

model = ChatOpenAI(temperature=0, model="gpt-3.5-turbo")

chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# %%
chain.invoke(
     "What do you see on the images in the database?"
)
